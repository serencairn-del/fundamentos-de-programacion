# %%
# TUPLA

numeros = (10,20,30,40)
frutas = ("Manzana", "Uva", "Cereza")
datos = ("Ricardo", 30, 2.65, True)

print(type(numeros))
print(type(frutas))
print(type(datos))

lista = [1]
datos2 = [5,]

print(type(lista))
print(type(datos2))

# %%
calificaciones = (88,90,100,85)

calif5 = 50
calif6 = 80

nuevas_calificaciones = calificaciones + (calif5, calif6)

print(calificaciones)
print(nuevas_calificaciones)

# %%
desordenada = (9,2,7,10,0,8,14,22,4)

print(type(desordenada))
print(desordenada)
lista = list(desordenada)
print()
print(type(lista))
print(lista)

print()
lista.sort()
print(lista)
ordenada = tuple(lista)
print()
print(type(ordenada))
print(ordenada)

# %%
contactos = {
    "Ricardo": "6655889933",
    "PEPE": "2255448811",
    "NANCY": "2255884444"
}

contactos = ["Cris"] = "2546987321"
contactos = ["Ricardo"] = "123456789"

# %%
print("LLaves")
for n in contactos.keys():
    print(n)

print("\nValores")
for v in contactos.values():
    print(v)

print("\nImmpresion completa")
for n, t in contactos.items():
    print(f"Nombre: {n}, Telefono: {t}")

# %%
def buscar_contacto(contactos, mombre):
    return

nom = input("Escirbe el nomnre del contacto que buscas: ")
telefono = buscar_contacto(contactos, nomnbre)
print(f"El telefono de {nombre} es: {telefono}")

# %%
nombre = "ricardo"

print(nombre.upper())
print(nombre.lower())
print(nombre.capitalize())

# %%
candidatos = {
    "E": 0,
    "X": 0,
    "C": 0 
}

cantidad = int(input("Cuántos votos van a ser: "))
conteo = 1

while conteo <= cantidad:
    voto = input(f"Ingresa el voto {conteo} (A, B o C): ")
    if voto.upper() in candidatos:
        print(f"Voto válido para {voto.upper()}")
        candidatos[vot.upper()] +1
        conto += 1
    else:
        print("El voto no es válido, vota nuevamente")

print("\nResultados: ")
for k,v in candidatos.items():
    print(f"Opción {k}, votos: {v}")

# %% [markdown]
# while conteo <= cantidad:
#       voto = input(f"Ingresa el voto {conteo} (A,B o C): ")
#       if voto.upper() in candidatos:
#         print(f"Voto para {voto.upper()}")
#         candidatos[voto.upper()] += 1
#       else:
#         print("El voto no es válido")
#
#
# for k,v in candidatos.items():
#    print(f"Opción {k}, votos {v}")
