# %% [markdown]
# # Sesión 1
# Practica para entender como funciona notebook y Python.

# %%
print("Hola")
# Out:
# Hola

# %% [markdown]
# # Variables
# Las variables en Python son tipos de datos que tienen doferente forma
# Numericas:
#     Enteros,
#     Flotante;
# Cadenas de caracteres,
# Booleanos,
# Compuestos.

# %%
NOMBRE = "Estrella"
EDAD = 23
es_estudiante = True
esta_activo = None
print(type(NOMBRE))
print(type(EDAD))
print(type(es_estudiante))
print(type(esta_activo))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'bool'>
# <class 'NoneType'>

# %%
nombre = "STAR"
edad = 23 
print("Hola", nombre, "ya vi que tienes", edad, "años de edad")
# Out:
# Hola STAR ya vi que tienes 23 años de edad

# %% [markdown]
# En este punto inicio el proyecto en Git
