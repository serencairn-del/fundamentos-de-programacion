# %% [markdown]
# # Sesión 1
# Practica para entender como funciona notebook y Python.

# %%
print("Hola")
# Out:
# Hola

# %% [markdown]
# ## Variables
# Las variables en Python son tipos de datos que tienen diferente forma
# * Numericas:
#     * Enteros
#     * Flotante
# * Cadenas de caracteres
# * Booleanos
# *  Compuestos

# %%
NOMBRE = "Estrella"
EDAD = 23
es_estudiante = True
esta_activo = None
print(type(NOMBRE))
print(type(EDAD))
print(type(es_estudiante))
print(type(esta_activo))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'bool'>
# <class 'NoneType'>

# %%
nombre = "STAR"
edad = 23 
print("Hola", nombre, "ya vi que tienes", edad, "años de edad")
# Out:
# Hola STAR ya vi que tienes 23 años de edad

# %% [markdown]
# En este punto inicio el proyecto en Git

# %% [markdown]
# ## Algoritmo para calcular velocidad

# %%
distancia = int(input("Ingrese la distancia en kilometros: "))
tiempo =  int(input("Ingrese el tiempo en horas: "))

print("El dato distancia es de tipo: ", type(distancia))
print("El dato tiempo es de tipo: ", type(tiempo))

velocidad = distancia / tiempo

print("La velocidad promedio es:", velocidad)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 distancia = int(input("Ingrese la distancia en kilometros: "))
#       2 tiempo =  int(input("Ingrese el tiempo en horas: "))
#       3
#       4 print("El dato distancia es de tipo: ", type(distancia))
#
# ValueError: invalid literal for int() with base 10: ''

# %% [markdown]
# ## Operadores

# %%
a = 4
b = 6

print(a + b)
print(a == b)
print(a < b)
print(a != b)
# Out:
# 10
# False
# True
# True

# %% [markdown]
# ## Entradas y salidas

# %%
edad_str = input("Ingresa tu edad: ")
print(type(edad_str))

edad = int(edad_str)
proximo_a = edad + 1

print( f"El proximo año tendras {proximo_a} años")
# Out:
# <class 'str'>
# El proximo año tendras 22 años

# %%
nombre = input("¿Cuál es tu nombre?")
edad = input("¿Cuál es tu edad?")

mensaje = f"¡Hey, {nombre}! ¡Tienes {edad} y estás super joven!"

print(mensaje)
# Out:
# Hey, Star! ¡Tienes 18 y estás super joven!
