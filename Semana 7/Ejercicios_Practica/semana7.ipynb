# %% [markdown]
# # Semana 7

# %%
archivo = open("saludo.txt", mode="a" )

archivo.write("Esto es una tercera línea\n")
archivo.close()
print("Se ha escrito en el archivo saludo.txt")
# Out:
# Se ha escrito en el archivo saludo.txt

# %%
archivo = open("notas.txt", mode="w")

archivo.write("Esto es una primera línea :)\n")
archivo.write("Esto es una segunda línea ^^\n")
archivo.write("Esto es una tercera línea :)\n")
archivo.close()

# %%
with open("bitacora.txt", mode="w") as archivo:
    archivo.write("Esto es una primera línea :)\n")
    archivo.write("Esto es una segunda línea ^^\n")
    archivo.write("Esto es una tercera línea :)\n")

with open("bitacora.txt", mode="a") as archivo:
    archivo.write("Esto es una cuarta línea ^^\n")

# %%
nombre = input("Ingrese su nombre: ")
edad = input("Ingrese su edad: ")

with open("datos_usuario.txt", mode="w") as archivo:
    archivo.write(f"Nombre: {nombre}, edad: {edad}\n")

print("Datos guardados. ^^")
# Out:
# Datos guardados. ^^

# %%
with open("poema.txt", mode="w") as archivo:
    archivo.write("Estoy en lo más profundo del Infierno, y la verdad; ya no sé rezar\n")
    archivo.write("Arthur Rimbaud...\n")
    archivo.write("No sé quién; pero si sé que a veces, cuando me examino el alma, la siento un poco quebrada\n")
    archivo.write("Juan Rulfo.\n")

# %%
with open("poema.txt", mode="r") as a:
    contenido = a.read()
    print(contenido)
# Out:
# Estoy en lo más profundo del Infierno, y la verdad; ya no sé rezar
# Arthur Rimbaud...
# No sé quién; pero si sé que a veces, cuando me examino el alma, la siento un poco quebrada
# Juan Rulfo.

# %% [markdown]
# ### Ejercicio 10: Listar líneas numeradas con `readlines()`
# **Enunciado:** Crea un programa que lea el archivo `nombres.txt` con `readlines()` y muestre cada línea numerada en consola.
# **Entrada:** Archivo `nombres.txt`:
# ```
# Ana
# Luis
# Maria
# ```
# **Salida (consola):**
# ```
# 1. Ana
# 2. Luis
# 3. Maria
# ```

# %%
with open("nombres.txt", "w") as archivo:
    archivo.write("Ana\n")
    archivo.write("Luis\n")
    archivo.write("Maria\n")

# %%
with open("nombres.txt", "r") as archivo:
    lin1 = archivo.readline()
    lin2 = archivo.readline()
    lin3 = archivo.readline()

print(f"1. {lin1.strip()}")
print(f"2. {lin2.strip()}")
print(f"3. {lin3.strip()}")
# Out:
# 1. Ana
# 2. Luis
# 3. Maria

# %% [markdown]
# ### Ejercicio 1: Mi primer archivo
# **Enunciado:** Crea un programa que abra el archivo `saludo.txt` en modo `'w'`, escriba el texto `Hola, mundo` con `write()` y cierre el archivo con `close()`. Al final, imprime un mensaje de confirmación.
# **Entrada:** Ninguna (el archivo `saludo.txt` no existe y se creará).
# **Salida:** Consola: `Archivo creado correctamente.` Archivo resultante `saludo.txt`: `Hola, mundo`

# %%
archivo = open("saludo2.txt", mode="w" )
archivo.write("Hola, mundo")

archivo.close()
print("Archivo creado correctamente.")

with open("saludo2.txt", mode="r") as a:
    contenido = a.read()
    print(contenido)
# Out:
# Archivo creado correctamente.
# Hola, mundo

# %% [markdown]
# ### Ejercicio 14: Buscar líneas con una palabra clave
# **Enunciado:** Crea un programa que recorra el archivo `articulo.txt` con `for` e imprima únicamente las líneas que contengan la palabra `Python`.
# **Entrada:** Archivo `articulo.txt`:
# ```
# Python es facil
# Java es dificil
# Python es poderoso
# ```
# **Salida (consola):**
# ```
# Python es facil
# Python es poderoso
# ```

# %%
with open("articulo.txt", "w") as archivo:
    archivo.write("Python es facil\n")
    archivo.write("Java es dificil\n")
    archivo.write("Python es poderoso\n")

# %%
with open("articulo.txt", mode= "r") as archivo:
    for linea in archivo:
        if "Python" in linea:
            print(linea.strip())
# Out:
# Python es facil
# Python es poderoso

# %% [markdown]
# ### Ejercicio 16: Copiar un archivo a otro
# **Enunciado:** Crea un programa que lea el contenido de `origen.txt` y lo escriba completo en un nuevo archivo `destino.txt`.
# **Entrada:** Archivo `origen.txt`: `Contenido a copiar`
# **Salida:** Consola: `Copia realizada.` Archivo resultante `destino.txt`: `Contenido a copiar`
